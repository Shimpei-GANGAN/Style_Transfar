# %%
"""

  Based:
  https://github.com/misgod/fast-neural-style-keras
  
"""
# Out:
# '\n\n  Based:\n  https://github.com/misgod/fast-neural-style-keras\n  \n'

# %%
#  一覧を表示
# !ls
# Out:
# 20181128_090930.jpg	    p.jpg		  wave_crop_pika_output.png
# fast-neural-style-keras     sample_data
# handdrawn_udnie_output.png  wave_crop_output.png

# %%
"""
  GitHubよりサンプルをダウンロード
"""
# !git clone https://github.com/misgod/fast-neural-style-keras.git
# Out:
# Cloning into 'fast-neural-style-keras'...
# remote: Enumerating objects: 153, done.
# remote: Total 153 (delta 0), reused 0 (delta 0), pack-reused 153
# Receiving objects: 100% (153/153), 122.55 MiB | 30.50 MiB/s, done.
# Resolving deltas: 100% (74/74), done.
# Checking out files: 100% (31/31), done.

# %%
"""
  ファイルの中身を確認
"""
# !ls -R fast-neural-style-keras/

# %%
# !cat fast-neural-style-keras/VGG16.py

# %%
"""
  プログラムをアップロード
"""
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bae95960-4d33-4de3-abea-e36ad0956c1e" name="files[]" multiple disabled />
#      <output id="result-bae95960-4d33-4de3-abea-e36ad0956c1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving VGG16.py to VGG16.py

# %%
#  ファイルの移動
# !mv -i VGG16.py fast-neural-style-keras/VGG16.py
# Out:
# mv: overwrite 'fast-neural-style-keras/VGG16.py'? yes

# %%
"""
  プログラムをアップロード
"""
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e670c5a9-98ab-404a-a9e0-c4a6a832a62d" name="files[]" multiple disabled />
#      <output id="result-e670c5a9-98ab-404a-a9e0-c4a6a832a62d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
#  ファイルの移動
# !mv -i transform.py fast-neural-style-keras/transform.py
# Out:
# mv: overwrite 'fast-neural-style-keras/transform.py'? yes

# %%
"""
  プログラムの実行
  
  # !python [プログラム名] [コンテンツ画像のパス] [スタイルの重み] [画像のブレンドパラメータ] [出力画像の名前]
"""
# !python fast-neural-style-keras/transform.py -i fast-neural-style-keras/images/content/101.jpg -s wave_crop -b 0.1 -o wave_crop
# Out:
# Using TensorFlow backend.
# 2018-12-07 04:07:01.370748: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-07 04:07:01.371246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-12-07 04:07:01.371294: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-07 04:07:01.830839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-12-07 04:07:01.830904: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-12-07 04:07:01.830935: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...

# %%
#  一覧を表示
# !ls
# Out:
# fast-neural-style-keras  sample_data  wave_crop_output.png

# %%
"""
  元画像を表示
"""
import cv2
import matplotlib.pyplot as plt
import os.path

# 座標軸の削除処理
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = './fast-neural-style-keras/images/content/101.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
"""
  画像を表示
"""
# 座標軸の削除処理
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = './fast-neural-style-keras/images/style/wave_crop.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
"""
  画像を表示
"""
# 座標軸の削除処理
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = 'wave_crop_output.png'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
"""
  画像をアップロード
"""
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec7df982-5ef9-487e-ad67-2c0f1d984410" name="files[]" multiple disabled />
#      <output id="result-ec7df982-5ef9-487e-ad67-2c0f1d984410">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 20181128_090930.jpg to 20181128_090930.jpg

# %%
"""
  手書き画像にスタイルを反映
"""
# !python fast-neural-style-keras/transform.py -i 20181128_090930.jpg -s udnie -b 0.5 -o handdrawn_udnie
# Out:
# Using TensorFlow backend.
# 2018-12-07 04:03:03.344564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-07 04:03:03.345057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-12-07 04:03:03.345100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-07 04:03:03.747694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-12-07 04:03:03.747751: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-12-07 04:03:03.747780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...

# %%
# !ls
# Out:
# 20181128_090930.jpg	    sample_data
# fast-neural-style-keras     udnie_keru_output.png
# handdrawn_udnie_output.png  wave_crop_keru_output.png
# p.jpg			    wave_crop_output.png
# ケルベロス.png		    wave_crop_pika_output.png

# %%
"""
  画像を表示
"""
# 座標軸の削除処理
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = 'handdrawn_udnie_output.png'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
"""
  画像をアップロード
"""
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6c8bb35b-46fc-4298-a581-426945c41b9a" name="files[]" multiple disabled />
#      <output id="result-6c8bb35b-46fc-4298-a581-426945c41b9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving p.jpg to p.jpg

# %%
"""
  手書き画像にスタイルを反映
"""
# !python fast-neural-style-keras/transform.py -i p.jpg -s wave_crop -b 0.1 -o wave_crop_pika
# Out:
# Using TensorFlow backend.
# 2018-12-07 04:02:05.304245: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-07 04:02:05.304749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-12-07 04:02:05.304805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-07 04:02:05.736752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-12-07 04:02:05.736816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-12-07 04:02:05.736845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...

# %%
"""
  画像を表示
"""
import cv2
import matplotlib.pyplot as plt
import os.path

# 座標軸の削除処理
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = 'wave_crop_pika_output.png'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
"""
  画像をアップロード
"""
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb492ef2-3ffb-4ba9-aa90-fbf08149d214" name="files[]" multiple disabled />
#      <output id="result-bb492ef2-3ffb-4ba9-aa90-fbf08149d214">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ケルベロス.png to ケルベロス.png

# %%
"""
  手書き画像にスタイルを反映
"""
# !python fast-neural-style-keras/transform.py -i ケルベロス.png -s wave_crop -b 0.1 -o wave_crop_keru
# Out:
# Using TensorFlow backend.
# 2018-12-07 04:53:06.551728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-12-07 04:53:06.552228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-12-07 04:53:06.552273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-12-07 04:53:06.987797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-12-07 04:53:06.987860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-12-07 04:53:06.987890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...

# %%
"""
  画像をアップロード
"""

# 座標軸の削除処理
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = 'udnie_keru_output.png'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
"""
  画像をアップロード
"""

# 座標軸の削除処理
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = 'wave_crop_keru_output.png'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)
